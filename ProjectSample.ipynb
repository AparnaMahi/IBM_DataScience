# %% [markdown]
# #  My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Aparna </b><br>
# DataScientist

# %% [markdown]
# <i> I am interested in data science because I believe that data science has the power to improve the human condition by helping us investigate phenomena, acquire new knowledge and integrate previous knowledge with new ideas.I heard that the excitement in data science is in the journey toward achieving three significant kinds of results: discovery, insights, and innovation.In my opinion it is really true.

# %% [markdown]
# ### Add two numbers and display the result

# %%
a=5
b=6
print("Sum :",a+b)
# Out:
# Sum : 11

# %% [markdown]
# ###### This shows an example for creating a table
#
# | Table         | Columns       | Count |
# | ------------- |:-------------:| -----:|
# | population    | males         | 1000  |
# |               | females       | 1300  |
# |               | total         | 2300  |
#
# ###### Blocked Quotes
#
# Welcome to the World of data.
#
# >This is good and very interesting.
#
# It is fun learning.
#
#
# ###### Numbered List
# <ol>
# <li>Veggies</li>
# <li>Milk</li>
# <li>Fish</li>
# <li>Meat</li>
# <li>Sugar</li>
# <li>Fruits</li>
# </ol>
#
# ###### Bulleted List
# <ul>
# <li>Veggies</li>
# <li>Milk</li>
# <li>Fish</li>
# <li>Meat</li>
# <li>Sugar</li>
# <li>Fruits</li></ul>
#
#
# ###### External Link
#
# <a href="https://www.google.com" >Link to Google</a>
#
#
# ###### Highlighting code
#
# Hi all  `welcome` to programming
#
#
# ###### Strikethrough
#
# <strike>This world is very beautiful<strike>
